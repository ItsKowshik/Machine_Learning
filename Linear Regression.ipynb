# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
#Sample values for regression
np.random.seed(100)
x = np.linspace(1,50)
y = 2*x +np.random.normal(0,5,50)
plt.title("Sample scatter for regression")
plt.scatter(x,y)

# %%
#Data preprocessing step
w = np.zeros((1,1))
b = 0
lr = 0.001
epoch = 100
x = x.reshape((len(x),1))
y = y.reshape((len(y),1))
losses = []
print(x.shape)
print(y.shape)
# Out:
# (50, 1)
# (50, 1)

# %%
for i in range(epoch):
    y_hat = np.dot(x,w) + b
    loss = np.mean((y_hat-y)**2)
    losses.append(loss)
    dw = np.dot(x.T,y_hat-y)*(1/50)
    db = np.sum(y_hat-y)*(1/50)
    w -= lr*dw
    b -= lr*db

print(losses)
print(w,b)
# Out:
# [3389.5905723667843, 88.54255299582915, 23.15388437723685, 21.858489351129844, 21.83268036732253, 21.832019939257247, 21.83185773645359, 21.831705474974353, 21.831553482655117, 21.83140156787064, 21.83124972679015, 21.831097959302753, 21.830946265371363, 21.830794644960232, 21.83064309803376, 21.830491624556327, 21.83034022449233, 21.830188897806185, 21.830037644462337, 21.82988646442525, 21.82973535765937, 21.829584324129204, 21.829433363799254, 21.82928247663403, 21.829131662598083, 21.82898092165597, 21.828830253772267, 21.82867965891156, 21.828529137038462, 21.828378688117596, 21.82822831211361, 21.828078008991145, 21.827927778714912, 21.82777762124957, 21.827627536559845, 21.82747752461047, 21.82732758536619, 21.827177718791777, 21.827027924851976, 21.82687820351162, 21.826728554735492, 21.826578978488453, 21.82642947473534, 21.82628004344101, 21.826130684570344, 21.82598139808826, 21.825832183959662, 21.825683042149468, 21.825533972622647, 21.82538497534416, 21.825236050279003,
# ...

# %%
plt.scatter(x,y)
plt.plot(x,np.dot(x,w)+b,'r')
plt.title("Simple Linear Regression")
plt.show()

# %%
plt.plot([i for i in range(epoch)],losses)
plt.title("Losses for epoch")
plt.show()

# %%
#Linear Regression by Normal Method
x_norm = np.hstack(((np.ones((len(x),1))),x))
theta = np.dot(np.dot(np.linalg.inv(np.dot(x.T,x)),x.T),y)
plt.scatter(x,y)
plt.plot(x,np.dot(x,theta),'r')
plt.title('Normal Method')
plt.show()
